# %% [markdown]
# <a href="https://colab.research.google.com/github/lueiyaya/ai-science-training-series-copy-mz/blob/main/07_AITestbeds/homework_files/homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SambaNova**
# **Homework:**
# >For BERT example, understand flags used in the script. Change values for flag ```--ntask``` and measure its effect on performance.
#
# The number of flage for ```ntask``` has been changed from 16 to 4, 8, and 32. However, 32 exceeds the limitation. The remining log files have updated to Github.
#
# *   [BertLarge_4.out](https://github.com/lueiyaya/ai-science-training-series-copy-mz/blob/main/07_AITestbeds/homework_files/Sambanova/BertLarge_4.out)
# *   [BertLarge_8.out](https://github.com/lueiyaya/ai-science-training-series-copy-mz/blob/main/07_AITestbeds/homework_files/Sambanova/BertLarge_8.out)
# *   [BertLarge_16.out](https://github.com/lueiyaya/ai-science-training-series-copy-mz/blob/main/07_AITestbeds/homework_files/Sambanova/BertLarge_16.out)
#
# The relationship between average loss and step across different ```ntask``` values is depicted in **Fig.1**. It demonstrates that the final average loss decreases as the ```ntask``` value increases.  reaching a minimum final average loss of 8.20143 when ntask equal 16. However, this is accompanied by an increase in computational time.

# %%
plt.show()

# %% [markdown]
# # **Graphcore**
# **Homework:**
# >Run MNIST example by changing values of the input parameters like batch-size, learning rate and number of epochs trained and observe and report the performance implications.
#
# The ```mnist_poptorch.py``` has been run. The number of batch-size has been changed from 8 to 4 and 16. Additionally, the value of learning rate has been changed from 0.03 to 0.01 and 0.1. The screenshots of output have updated to Github.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; **Batch-size:**
# *   [batch_size_4.png](https://github.com/lueiyaya/ai-science-training-series-copy-mz/blob/main/07_AITestbeds/homework_files/Graphcore/batch_size/batch_size_4.png)
# *   [batch_size_8.png](https://github.com/lueiyaya/ai-science-training-series-copy-mz/blob/main/07_AITestbeds/homework_files/Graphcore/batch_size/batch_size_8.png)
# *   [batch_size_16.png](https://github.com/lueiyaya/ai-science-training-series-copy-mz/blob/main/07_AITestbeds/homework_files/Graphcore/batch_size/batch_size_16.png)
#
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; **learning rate:**
# *   [learning_rate_0.01.png](https://github.com/lueiyaya/ai-science-training-series-copy-mz/blob/main/07_AITestbeds/homework_files/Graphcore/learning_rate/learning_rate_0.01.png)
# *   [learning_rate_0.03.png](https://github.com/lueiyaya/ai-science-training-series-copy-mz/blob/main/07_AITestbeds/homework_files/Graphcore/learning_rate/learning_rate_0.03.png)
# *   [learning_rate_0.1.png](https://github.com/lueiyaya/ai-science-training-series-copy-mz/blob/main/07_AITestbeds/homework_files/Graphcore/learning_rate/learning_rate_0.1.png)
#
# The relationship between accuracy and input parameters including batch-size and learning rate is depicted in **Fig.2**. **Fig.2.(a)** shows a positive correlation between batch size and accuracy, indicating that as the batch size increases, there is a consistent rise in accuracy. However, given that the accuracy metric is already surpassing 98%, the observed improvement is relatively marginal, amounting to approximately 3%. **Fig.2.(b)** illustrates the relationship between the learning rate and accuracy, revealing a non-linear trend. It might be attributed to the minor influence of learning rate adjustments on a model already achieving accuracy above 98%.

# %%
plt.show()

# %% [markdown]
# # **Cerebras**
# **Homework:**
# >Run BERT example with different batch sizes like 512, 2048 and observe the performance difference.
#
# The ```R_2.1.1/modelzoo/modelzoo/transformers/pytorch/bert/run.py``` has been run. The number of batch size has been changed from 1024 to 512 and 2048. The log files of output have updated to Github.
#
# *   [mytest_Bert-512.log](https://github.com/lueiyaya/ai-science-training-series-copy-mz/blob/main/07_AITestbeds/homework_files/Cerebras/mytest_Bert-512.log)
# *   [mytest_Bert-1024.log](https://github.com/lueiyaya/ai-science-training-series-copy-mz/blob/main/07_AITestbeds/homework_files/Cerebras/mytest_Bert-1024.log)
# *   [mytest_Bert-2048.log](https://github.com/lueiyaya/ai-science-training-series-copy-mz/blob/main/07_AITestbeds/homework_files/Cerebras/mytest_Bert-2048.log)
#
# The relationship between loss and step across different batch size values is depicted in **Fig.3**. The batch size of 2048 exhibits a more consistent reduction in loss, with minimal fluctuations. However, it does not present a significant minimum value for the loss, implying a potential plateau in performance gains at this batch size.

# %%
plt.show()

# %% [markdown]
# # **Groq**
# **Homework:**
# >Run BERT example with custom input instead of dummy input.
#
# The inputs of ```bert_tiny.py``` has been modified and run.  The input has shifted from a dummy tensor, consisting entirely of ones, to a customized input utilizing text from "Star Wars," tokenized with the  ```"M-FAC/bert-tiny-finetuned-sst2"``` model.
# The detail of the modifications is shown as below.
#
#
# ![detail](https://github.com/lueiyaya/ai-science-training-series-copy-mz/raw/main/07_AITestbeds/homework_files/Groq/custom_inputs.png)
#
# The output files of dummy-intputs and custom-inputs have updated to Github.
# *   [dummy_inputs.log](https://github.com/lueiyaya/ai-science-training-series-copy-mz/blob/main/07_AITestbeds/homework_files/Groq/bert_tiny_dummy.txt)
# *   [customs_inputs.log](https://github.com/lueiyaya/ai-science-training-series-copy-mz/blob/main/07_AITestbeds/homework_files/Groq/bert_tiny_custom.txt)
