# %% [markdown]
# <a href="https://colab.research.google.com/github/lueiyaya/ai-science-training-series-copy-mz/blob/main/04_intro_to_llms/Homework_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Let's write an elementary tokenizer that uses words as tokens.
#
# We will use Mark Twain's _Life On The Mississippi_ as a test bed. The text is in the accompanying file 'Life_On_The_Mississippi.txt'
#
# Here's a not-terribly-good such tokenizer:

# %%
wdict = {}
with open('Life_On_The_Mississippi.txt', 'r') as L:
    line = L.readline()
    nlines = 1
    while line:

        words = line.split()
        for word in words:
            if wdict.get(word) is not None:
                wdict[word] += 1
            else:
                wdict[word] = 1
        line = L.readline()
        nlines += 1

nitem = 0 ; maxitems = 100
for item in wdict.items():
    nitem += 1
    print(item)
    if nitem == maxitems: break
# Out:
# ('\ufeffThe', 1)
# ('Project', 79)
# ('Gutenberg', 22)
# ('eBook', 4)
# ('of', 4469)
# ('Life', 5)
# ('on', 856)
# ('the', 8443)
# ('Mississippi', 104)
# ('This', 127)
# ('ebook', 2)
# ('is', 1076)
# ('for', 1017)
# ('use', 34)
# ('anyone', 4)
# ('anywhere', 8)
# ('in', 2381)
# ('United', 36)
# ('States', 26)
# ('and', 5692)
# ('most', 119)
# ('other', 223)
# ('parts', 5)
# ('world', 40)
# ('at', 676)
# ('no', 325)
# ('cost', 18)
# ('with', 1053)
# ('almost', 37)
# ('restrictions', 2)
# ('whatsoever.', 2)
# ('You', 92)
# ('may', 85)
# ('copy', 12)
# ('it,', 199)
# ('give', 67)
# ('it', 1382)
# ('away', 107)
# ('or', 561)
# ('re-use', 2)
# ('under', 112)
# ('terms', 22)
# ('License', 8)
# ('included', 2)
# ('this', 591)
# ('online', 4)
# ('www.gutenberg.org.', 4)
# ('If', 85)
# ('you', 813)
# ('are', 361)
# ('not', 680)
# ('located', 9)
# ('States,', 8)
# ('will', 287)
# ('have', 557)
# ('to', 3518)
# ('check', 4)
# ('laws', 13)
# ('country', 50)
# ('where', 152)
# ('before', 150)
# ('using', 10)
# ('eBook.', 2)
# ('Title:', 1)
# ('Author:', 1)
# ('Mark', 2)
# ('Twain', 2)
# ('Release', 1)
# ('date:', 1)
# ('July', 7)
# ('10,', 2)
# ('2004', 1)
# ('[eBook', 1)
# ('#245]', 1)
# ('Most', 4)
# ('recently', 3)
# ('updated:', 1)
# ('January', 2)
# ('1,', 2)
# ('2021', 1)
# ('Language:', 1)
# ('English', 7)
# ('Credits:', 1)
# ('Produced', 2)
# ('by', 623)
# ('David', 2)
# ('Widger.', 2)
# ('Earliest', 2)
# ('PG', 3)
# ('text', 4)
# ('edition', 3)
# ('produced', 15)
# ('Graham', 2)
# ('Allan', 2)
# ('***', 4)
# ('START', 1)
# ('OF', 16)
# ('THE', 29)
# ('PROJECT', 4)
# ('GUTENBERG', 3)

# %% [markdown]
# This is unsatisfactory for a few reasons:
#
# * There are non-ASCII (Unicode) characters that should be stripped (the so-called "Byte-Order Mark" or BOM \ufeff at the beginning of the text);
#
# * There are punctuation marks, which we don't want to concern ourselves with;
#
# * The same word can appear capitalized, or lower-case, or with its initial letter upper-cased, whereas we want them all to be normalized to lower-case.
#
# Part 1 of this assignment: insert code in this loop to operate on the str variable 'line' so as to fix these problems before 'line' is split into words.
#
# A hint to one possible way to do this: use the 'punctuation' character definition in the Python 'string' module, the 'maketrans' and 'translate' methods of Python's str class, to eliminate punctuation, and the regular expression ('re') Python module to eliminate any Unicode---it is useful to know that the regular expression r'[^\x00-x7f]' means "any character not in the vanilla ASCII set.
#
# Part 2: Add code to sort the contents of wdict by word occurrence frequency.  What are the top 100 most frequent word tokens?  Adding up occurrence frequencies starting from the most frequent words, how many distinct words make up the top 90% of word occurrences in this "corpus"?
#
# For this part, the docs of Python's 'sorted' and of the helper 'itemgetter' from 'operator' reward study.
#
# Write your modified code in the cell below.

# %% [markdown]
# ## Part 1: Modify the code

# %%
import string
import re

wdict = {}
with open('Life_On_The_Mississippi.txt', 'r') as L:
    line = L.readline()
    nlines = 1
    trans_table = str.maketrans('','',string.punctuation)
    while line:
        line= re.sub(r'[^\x00-x7f]','',line)
        line = line.translate(trans_table).lower()

        words = line.split()
        for word in words:
            if wdict.get(word) is not None:
                wdict[word] += 1
            else:
                wdict[word] = 1
        line = L.readline()
        nlines += 1

nitem = 0 ; maxitems = 100
for item in wdict.items():
    nitem += 1
    print(item)
    if nitem == maxitems: break
# Out:
# ('the', 10012)
# ('project', 90)
# ('gutenberg', 87)
# ('ebook', 13)
# ('of', 4532)
# ('life', 89)
# ('on', 947)
# ('mississippi', 159)
# ('this', 781)
# ('is', 1148)
# ('for', 1095)
# ('use', 48)
# ('anone', 5)
# ('anwhere', 18)
# ('in', 2593)
# ('united', 37)
# ('states', 54)
# ('and', 5892)
# ('most', 124)
# ('other', 270)
# ('parts', 10)
# ('world', 68)
# ('at', 750)
# ('no', 422)
# ('cost', 25)
# ('with', 1081)
# ('almost', 38)
# ('restrictions', 2)
# ('whatsoever', 2)
# ('you', 117)
# ('ma', 90)
# ('cop', 17)
# ('it', 2294)
# ('give', 81)
# ('awa', 172)
# ('or', 581)
# ('reuse', 2)
# ('under', 119)
# ('terms', 26)
# ('license', 24)
# ('included', 3)
# ('online', 4)
# ('wwwgutenbergorg', 5)
# ('if', 381)
# ('ou', 916)
# ('are', 387)
# ('not', 722)
# ('located', 9)
# ('will', 301)
# ('have', 571)
# ('to', 3593)
# ('check', 4)
# ('laws', 17)
# ('countr', 76)
# ('where', 174)
# ('before', 208)
# ('using', 11)
# ('title', 3)
# ('author', 3)
# ('mark', 24)
# ('twain', 26)
# ('release', 1)
# ('date', 18)
# ('jul', 7)
# ('10', 10)
# ('2004', 1)
# ('245', 1)
# ('recentl', 4)
# ('updated', 2)
# ('januar', 3)
# ('1', 13)
# ('2021', 1)
# ('language', 12)
# ('english', 11)
# ('credits', 1)
# ('produced', 22)
# ('b', 726)
# ('david', 2)
# ('widger', 2)
# ('earliest', 7)
# ('pg', 3)
# ('text', 4)
# ('edition', 4)
# ('graham', 2)
# ('allan', 2)
# ('start', 31)
# ('table', 6)
# ('contents', 6)
# ('chapter', 125)
# ('i', 2205)
# ('well', 191)
# ('worth', 43)
# ('reading', 13)
# ('aboutit', 1)
# ('remarkableinstead', 1)
# ('widening', 2)
# ('towards', 9)
# ('its', 323)
# ('mouth', 53)
# ('grows', 3)

# %% [markdown]
# ## Part 2 top 100 most frequent word and 90% vocab

# %%
from operator import itemgetter

# %%
wdict_sorted = sorted(wdict.items(), key=itemgetter(1), reverse= True)

# %%
# so the top 100 most frequent words
wdict_sorted[0:100]
# Out:
# [('the', 10012),
#  ('and', 5892),
#  ('of', 4532),
#  ('a', 4055),
#  ('to', 3593),
#  ('in', 2593),
#  ('it', 2294),
#  ('i', 2205),
#  ('was', 2114),
#  ('that', 1724),
#  ('he', 1402),
#  ('is', 1148),
#  ('for', 1095),
#  ('with', 1081),
#  ('his', 961),
#  ('had', 961),
#  ('but', 952),
#  ('on', 947),
#  ('ou', 916),
#  ('as', 881),
#  ('this', 781),
#  ('at', 750),
#  ('b', 726),
#  ('not', 722),
#  ('all', 720),
#  ('one', 688),
#  ('an', 675),
#  ('there', 629),
#  ('were', 625),
#  ('be', 617),
#  ('m', 583),
#  ('or', 581),
#  ('from', 577),
#  ('have', 571),
#  ('out', 541),
#  ('so', 537),
#  ('up', 529),
#  ('him', 523),
#  ('we', 519),
#  ('me', 516),
#  ('when', 505),
#  ('would', 478),
#  ('which', 476),
#  ('river', 457),
#  ('them', 425),
#  ('no', 422),
#  ('then', 405),
#  ('said', 399),
#  ('are', 387),
#  ('man', 383),
#  ('if', 381),
#  ('their', 378),
#  ('now', 369),
#  ('about', 346),
#  ('time', 337),
#  ('been', 335),
#  ('down', 328),
#  ('its', 323),
#  ('ever', 323),
#  ('could', 313),
#  ('has', 305),
#  ('will', 301),
#  ('into', 300),
#  ('what', 285),
#  ('our', 280),
#  ('her', 278),
#  ('two', 273),
#  ('do', 271),
#  ('other', 270),
#  ('some', 269),
#  ('new', 259),
#  ('got', 234),
#  ('these', 233),
#  ('she', 233),
#  ('who', 229),
#  ('more', 226),
#  ('water', 225),
#  ('did', 214),
#  ('before', 208),
#  ('over', 202),
#  ('wa', 202),
#  ('hundred', 200),
#  ('upon', 200),
#  ('here', 199),
#  ('after', 195),
#  ('da', 193),
#  ('than', 192),
#  ('well', 191),
#  ('through', 191),
#  ('get', 190),
#  ('old', 186),
#  ('can', 185),
#  ('boat', 184),
#  ('went', 183),
#  ('never', 182),
#  ('good', 181),
#  ('ears', 180),
#  ('see', 176),
#  ('know', 175),
#  ('where', 174)]

# %%
## calculate the total num of the dict
count = 0
for item in wdict.items():
  count += item[1]
print(f'the total number of the book is {count}')
# Out:
# the total number of the book is 147419

# %%
## calculate the number of distinct words make up the top 90% of word occurrences in this "corpus"
count_distinct_words = 0
for word in wdict_sorted:
  count_distinct_words += item[1]
  if count_distinct_words / count > 0.9:break
print(f'the number of distinct words make up the top 90% of word occurrences in this "corpus" is {count_distinct_words}')
# Out:
# the number of distinct words make up the top 90% of word occurrences in this "corpus" is 14352

# %%
print('the detail of the top 90%  ')
wdict_sorted[:count_distinct_words]
# Out:
# the detail of the top 90%
# [('the', 10012),
#  ('and', 5892),
#  ('of', 4532),
#  ('a', 4055),
#  ('to', 3593),
#  ('in', 2593),
#  ('it', 2294),
#  ('i', 2205),
#  ('was', 2114),
#  ('that', 1724),
#  ('he', 1402),
#  ('is', 1148),
#  ('for', 1095),
#  ('with', 1081),
#  ('his', 961),
#  ('had', 961),
#  ('but', 952),
#  ('on', 947),
#  ('ou', 916),
#  ('as', 881),
#  ('this', 781),
#  ('at', 750),
#  ('b', 726),
#  ('not', 722),
#  ('all', 720),
#  ('one', 688),
#  ('an', 675),
#  ('there', 629),
#  ('were', 625),
#  ('be', 617),
#  ('m', 583),
#  ('or', 581),
#  ('from', 577),
#  ('have', 571),
#  ('out', 541),
#  ('so', 537),
#  ('up', 529),
#  ('him', 523),
#  ('we', 519),
#  ('me', 516),
#  ('when', 505),
#  ('would', 478),
#  ('which', 476),
#  ('river', 457),
#  ('them', 425),
#  ('no', 422),
#  ('then', 405),
#  ('said', 399),
#  ('are', 387),
#  ('man', 383),
#  ('if', 381),
#  ('their', 378),
#  ('now', 369),
#  ('about', 346),
#  ('time', 337),
#  ('been', 335),
#  ('down', 328),
#  ('its', 323),
#  ('ever', 323),
#  ('could', 313),
#  ('has', 305),
#  ('will', 301),
#  ('into', 300),
#  ('what', 285),
#  ('our', 280),
#  ('her', 278),
#  ('two', 273),
#  ('do', 271),
#  ('other', 270),
#  ('some', 269),
#  ('new', 259),
#  ('got', 234),
#  ('these', 233),
#  ('she', 233),
#  ('who', 229),
#  ('more', 226),
#  ('water', 225),
#  ('did', 214),
#  ('before', 208),
#  ('over', 202),
#  ('wa', 202),
#  ('hundred', 200),
#  ('upon', 200),
#  ('here', 199),
#  ('after', 195),
#  ('da', 193),
#  ('than', 192),
#  ('well', 191),
#  ('through', 191),
#  ('get', 190),
#  ('old', 186),
#  ('can', 185),
#  ('boat', 184),
#  ('went', 183),
#  ('never', 182),
#  ('good', 181),
#  ('ears', 180),
#  ('see', 176),
#  ('know', 175),
#  ('where', 174),
#  ('awa', 172),
#  ('come', 172),
#  ('onl', 169),
#  ('ver', 169),
#  ('little', 168),
#  ('back', 168),
#  ('go', 166),
#  ('head', 163),
#  ('like', 162),
#  ('made', 162),
#  ('mr', 161),
#  ('great', 161),
#  ('just', 161),
#  ('night', 160),
#  ('mississippi', 159),
#  ('again', 158),
#  ('came', 156),
#  ('off', 155),
#  ('how', 155),
#  ('long', 154),
#  ('such', 154),
#  ('first', 152),
#  ('three', 151),
#  ('miles', 149),
#  ('place', 148),
#  ('take', 145),
#  ('still', 145),
#  ('around', 143),
#  ('along', 140),
#  ('alwas', 139),
#  ('people', 138),
#  ('thing', 137),
#  ('st', 135),
#  ('men', 130),
#  ('another', 128),
#  ('work', 127),
#  ('last', 127),
#  ('town', 126),
#  ('make', 126),
#  ('chapter', 125),
#  ('most', 124),
#  ('orleans', 124),
#  ('those', 123),
#  ('sa', 122),
#  ('same', 121),
#  ('dont', 120),
#  ('under', 119),
#  ('much', 119),
#  ('saw', 119),
#  ('must', 119),
#  ('once', 118),
#  ('too', 118),
#  ('going', 118),
#  ('you', 117),
#  ('captain', 117),
#  ('without', 117),
#  ('used', 116),
#  ('next', 115),
#  ('pilot', 114),
#  ('left', 111),
#  ('might', 111),
#  ('being', 110),
#  ('pilots', 109),
#  ('took', 109),
#  ('thousand', 105),
#  ('while', 105),
#  ('oung', 105),
#  ('us', 104),
#  ('seen', 103),
#  ('das', 101),
#  ('sas', 101),
#  ('louis', 97),
#  ('tell', 97),
#  ('look', 95),
#  ('told', 95),
#  ('ago', 93),
#  ('put', 93),
#  ('dead', 92),
#  ('end', 91),
#  ('right', 91),
#  ('project', 90),
#  ('ma', 90),
#  ('hand', 90),
#  ('began', 90),
#  ('life', 89),
#  ('course', 88),
#  ('gutenberg', 87),
#  ('feet', 87),
#  ('times', 86),
#  ('done', 85),
#  ('four', 84),
#  ('island', 84),
#  ('nothing', 84),
#  ('ten', 83),
#  ('half', 83),
#  ('should', 83),
#  ('give', 81),
#  ('also', 81),
#  ('enough', 81),
#  ('dollars', 81),
#  ('et', 80),
#  ('find', 80),
#  ('things', 79),
#  ('between', 79),
#  ('name', 79),
#  ('full', 79),
#  ('high', 78),
#  ('five', 78),
#  ('yes', 78),
#  ('part', 77),
#  ('let', 77),
#  ('countr', 76),
#  ('big', 76),
#  ('found', 76),
#  ('point', 76),
#  ('moment', 76),
#  ('himself', 75),
#  ('above', 74),
#  ('black', 74),
#  ('each', 73),
#  ('heard', 73),
#  ('even', 73),
#  ('because', 73),
#  ('thought', 73),
#  ('run', 71),
#  ('cit', 71),
#  ('seemed', 71),
#  ('six', 70),
#  ('la', 70),
#  ('side', 69),
#  ('didnt', 69),
#  ('knew', 69),
#  ('world', 68),
#  ('war', 68),
#  ('ear', 68),
#  ('set', 68),
#  ('think', 68),
#  ('steamboat', 68),
#  ('boats', 68),
#  ('prett', 68),
#  ('presentl', 68),
#  ('watch', 67),
#  ('anthing', 67),
#  ('soon', 66),
#  ('read', 65),
#  ('talk', 65),
#  ('gave', 65),
#  ('kind', 65),
#  ('bixb', 65),
#  ('till', 64),
#  ('general', 64),
#  ('mself', 63),
#  ('better', 63),
#  ('business', 63),
#  ('poor', 63),
#  ('wheel', 63),
#  ('far', 62),
#  ('fift', 62),
#  ('wh', 62),
#  ('sort', 62),
#  ('mind', 61),
#  ('fact', 61),
#  ('among', 61),
#  ('matter', 61),
#  ('sir', 61),
#  ('am', 60),
#  ('since', 60),
#  ('hands', 60),
#  ('gone', 60),
#  ('whole', 59),
#  ('both', 59),
#  ('few', 59),
#  ('stood', 59),
#  ('during', 58),
#  ('turned', 58),
#  ('fell', 58),
#  ('white', 57),
#  ('sometimes', 57),
#  ('called', 57),
#  ('trip', 57),
#  ('shore', 57),
#  ('land', 56),
#  ('bo', 56),
#  ('deck', 56),
#  ('keep', 56),
#  ('below', 55),
#  ('something', 55),
#  ('together', 55),
#  ('states', 54),
#  ('want', 54),
#  ('several', 54),
#  ('morning', 54),
#  ('near', 54),
#  ('bank', 54),
#  ('mouth', 53),
#  ('pilothouse', 53),
#  ('own', 53),
#  ('mone', 52),
#  ('until', 52),
#  ('help', 51),
#  ('house', 51),
#  ('association', 50),
#  ('brown', 50),
#  ('nearl', 50),
#  ('often', 50),
#  ('deep', 50),
#  ('looked', 50),
#  ('large', 49),
#  ('fire', 49),
#  ('against', 49),
#  ('asked', 49),
#  ('letter', 49),
#  ('use', 48),
#  ('home', 48),
#  ('book', 48),
#  ('distance', 48),
#  ('turn', 48),
#  ('however', 48),
#  ('ees', 47),
#  ('best', 47),
#  ('cannot', 47),
#  ('themselves', 46),
#  ('bos', 45),
#  ('banks', 45),
#  ('reached', 45),
#  ('remember', 45),
#  ('cant', 45),
#  ('ee', 45),
#  ('fine', 44),
#  ('state', 44),
#  ('started', 44),
#  ('behind', 44),
#  ('small', 44),
#  ('worth', 43),
#  ('face', 43),
#  ('stand', 43),
#  ('toward', 43),
#  ('nobod', 43),
#  ('whom', 43),
#  ('rest', 43),
#  ('sent', 43),
#  ('coming', 43),
#  ('hour', 42),
#  ('less', 42),
#  ('ground', 42),
#  ('mile', 42),
#  ('foot', 42),
#  ('steamer', 42),
#  ('person', 42),
#  ('everbod', 42),
#  ('twelve', 42),
#  ('works', 42),
#  ('does', 41),
#  ('child', 41),
#  ('getting', 41),
#  ('kept', 41),
#  ('whose', 41),
#  ('middle', 41),
#  ('low', 40),
#  ('pa', 40),
#  ('children', 40),
#  ('having', 40),
#  ('fifteen', 40),
#  ('death', 40),
#  ('others', 40),
#  ('memor', 40),
#  ('sure', 40),
#  ('aint', 40),
#  ('door', 40),
#  ('thats', 40),
#  ('hear', 39),
#  ('word', 39),
#  ('shall', 39),
#  ('became', 39),
#  ('heart', 39),
#  ('sight', 39),
#  ('lodge', 39),
#  ('almost', 38),
#  ('bod', 38),
#  ('region', 38),
#  ('itself', 38),
#  ('within', 38),
#  ('de', 38),
#  ('certain', 38),
#  ('passed', 38),
#  ('light', 38),
#  ('everthing', 38),
#  ('hours', 38),
#  ('lost', 38),
#  ('except', 38),
#  ('united', 37),
#  ('become', 37),
#  ('struck', 37),
#  ('beautiful', 37),
#  ('wide', 37),
#  ('current', 37),
#  ('close', 37),
#  ('case', 37),
#  ('houses', 37),
#  ('famil', 37),
#  ('else', 37),
#  ('tried', 37),
#  ('perhaps', 37),
#  ('able', 36),
#  ('later', 36),
#  ('wanted', 36),
#  ('received', 36),
#  ('months', 36),
#  ('oh', 36),
#  ('none', 36),
#  ('steam', 36),
#  ('sta', 36),
#  ('deal', 36),
#  ('comes', 35),
#  ('hard', 35),
#  ('fast', 35),
#  ('couple', 35),
#  ('quarter', 35),
#  ('chief', 35),
#  ('month', 35),
#  ('air', 35),
#  ('negro', 35),
#  ('minutes', 35),
#  ('talking', 35),
#  ('killed', 35),
#  ('words', 35),
#  ('felt', 35),
#  ('strong', 35),
#  ('finall', 35),
#  ('dark', 34),
#  ('thirt', 34),
#  ('present', 34),
#  ('order', 34),
#  ('shape', 34),
#  ('crossing', 34),
#  ('bend', 34),
#  ('earl', 33),
#  ('red', 33),
#  ('change', 33),
#  ('rise', 33),
#  ('built', 33),
#  ('standing', 33),
#  ('died', 33),
#  ('cut', 33),
#  ('brought', 33),
#  ('voice', 33),
#  ('aboard', 33),
#  ('ashore', 33),
#  ('ill', 33),
#  ('across', 33),
#  ('show', 33),
#  ('followed', 33),
#  ('wages', 33),
#  ('former', 33),
#  ('bear', 33),
#  ('per', 33),
#  ('histor', 32),
#  ('seems', 32),
#  ('upper', 32),
#  ('places', 32),
#  ('south', 32),
#  ('hardl', 32),
#  ('stage', 32),
#  ('ive', 32),
#  ('mean', 32),
#  ('street', 32),
#  ('paul', 32),
#  ('learn', 32),
#  ('compan', 32),
#  ('effect', 32),
#  ('start', 31),
#  ('government', 31),
#  ('nor', 31),
#  ('missouri', 31),
#  ('thus', 31),
#  ('speak', 31),
#  ('therefore', 31),
#  ('taken', 31),
#  ('ones', 31),
#  ('past', 31),
#  ('number', 31),
#  ('mate', 31),
#  ('leave', 31),
#  ('different', 31),
#  ('couldnt', 31),
#  ('eas', 31),
#  ('known', 31),
#  ('question', 30),
#  ('plain', 30),
#  ('uncle', 30),
#  ('form', 30),
#  ('vast', 30),
#  ('steamboats', 30),
#  ('single', 30),
#  ('seven', 30),
#  ('means', 30),
#  ('earth', 30),
#  ('room', 30),
#  ('doen', 30),
#  ('village', 30),
#  ('cairo', 30),
#  ('line', 30),
#  ('barl', 30),
#  ('streets', 30),
#  ('wish', 30),
#  ('theres', 30),
#  ('friends', 30),
#  ('friend', 30),
#  ('answer', 29),
#  ('smoke', 29),
#  ('probabl', 29),
#  ('front', 29),
#  ('alone', 29),
#  ('making', 29),
#  ('moved', 29),
#  ('rock', 29),
#  ('passengers', 29),
#  ('information', 29),
#  ('woman', 29),
#  ('hold', 29),
#  ('forward', 29),
#  ('feel', 29),
#  ('sleep', 29),
#  ('believe', 29),
#  ('held', 29),
#  ('ladies', 28),
#  ('dropped', 28),
#  ('population', 28),
#  ('quite', 28),
#  ('twent', 28),
#  ('towns', 28),
#  ('solid', 28),
#  ('ought', 28),
#  ('fort', 28),
#  ('fellow', 28),
#  ('experience', 28),
#  ('hurricane', 28),
#  ('eight', 28),
#  ('church', 28),
#  ('chance', 28),
#  ('either', 28),
#  ('shot', 28),
#  ('trouble', 27),
#  ('account', 27),
#  ('tr', 27),
#  ('goes', 27),
#  ('bad', 27),
#  ('lake', 27),
#  ('rivers', 27),
#  ('changed', 27),
#  ('stream', 27),
#  ('human', 27),
#  ('napoleon', 27),
#  ('lot', 27),
#  ('names', 27),
#  ('wont', 27),
#  ('wind', 27),
#  ('running', 27),
#  ('anbod', 27),
#  ('rather', 27),
#  ('board', 27),
#  ('attention', 27),
#  ('electronic', 27),
#  ('terms', 26),
#  ('twain', 26),
#  ('waters', 26),
#  ('heav', 26),
#  ('west', 26),
#  ('square', 26),
#  ('vicksburg', 26),
#  ('free', 26),
#  ('short', 26),
#  ('particular', 26),
#  ('silence', 26),
#  ('carried', 26),
#  ('son', 26),
#  ('straight', 26),
#  ('piloting', 26),
#  ('interest', 26),
#  ('trade', 26),
#  ('cost', 25),
#  ('captains', 25),
#  ('caught', 25),
#  ('cub', 25),
#  ('stor', 25),
#  ('instance', 25),
#  ('added', 25),
#  ('idea', 25),
#  ('top', 25),
#  ('happened', 25),
#  ('visited', 25),
#  ('wouldnt', 25),
#  ('mabe', 25),
#  ('wonderful', 25),
#  ('hat', 25),
#  ('im', 25),
#  ('call', 25),
#  ('looking', 25),
#  ('stopped', 25),
#  ('ran', 25),
#  ('brother', 25),
#  ('reef', 25),
#  ('taking', 25),
#  ('sound', 25),
#  ('view', 25),
#  ('die', 25),
#  ('law', 25),
#  ('given', 25),
#  ('stephen', 25),
#  ('memphis', 25),
#  ('rich', 25),
#  ('license', 24),
#  ('mark', 24),
#  ('kill', 24),
#  ('truth', 24),
#  ('instead', 24),
#  ('mud', 24),
#  ('third', 24),
#  ('weeks', 24),
#  ('arkansas', 24),
#  ('nature', 24),
#  ('forest', 24),
#  ('sun', 24),
#  ('wait', 24),
#  ('wasnt', 24),
#  ('saing', 24),
#  ('though', 24),
#  ('laid', 24),
#  ('stop', 24),
#  ('broke', 24),
#  ('hope', 24),
#  ('least', 24),
#  ('bar', 24),
#  ('plantation', 24),
#  ('spirit', 24),
#  ('alread', 24),
#  ('placed', 24),
#  ('sunda', 24),
#  ('foundation', 24),
#  ('indian', 23),
#  ('begin', 23),
#  ('southern', 23),
#  ('fair', 23),
#  ('literar', 23),
#  ('second', 23),
#  ('lower', 23),
#  ('living', 23),
#  ('result', 23),
#  ('higher', 23),
#  ('born', 23),
#  ('somebod', 23),
#  ('north', 23),
#  ('late', 23),
#  ('believed', 23),
#  ('trees', 23),
#  ('plent', 23),
#  ('ended', 23),
#  ('beginning', 23),
#  ('nine', 23),
#  ('send', 23),
#  ('bottom', 23),
#  ('ouve', 23),
#  ('doing', 23),
#  ('wife', 23),
#  ('true', 23),
#  ('freight', 23),
#  ('learned', 23),
#  ('week', 23),
#  ('outside', 23),
#  ('oclock', 23),
#  ('purpose', 23),
#  ('york', 23),
#  ('stock', 23),
#  ('public', 23),
#  ('produced', 22),
#  ('mans', 22),
#  ('girl', 22),
#  ('meet', 22),
#  ('cutoff', 22),
#  ('subject', 22),
#  ('picture', 22),
#  ('lived', 22),
#  ('remained', 22),
#  ('open', 22),
#  ('breath', 22),
#  ('women', 22),
#  ('filled', 22),
#  ('seem', 22),
#  ('bell', 22),
#  ('persons', 22),
#  ('suddenl', 22),
#  ('hall', 22),
#  ('met', 22),
#  ('longer', 22),
#  ('fresh', 21),
#  ('summer', 21),
#  ('piece', 21),
#  ('further', 21),
#  ('awful', 21),
#  ('sister', 21),
#  ('entered', 21),
#  ('spot', 21),
#  ('talked', 21),
#  ('tring', 21),
#  ('according', 21),
#  ('drink', 21),
#  ('perfect', 21),
#  ('george', 21),
#  ('neither', 21),
#  ('center', 21),
#  ('sie', 21),
#  ('afterward', 21),
#  ('service', 21),
#  ('likel', 21),
#  ('sugar', 21),
#  ('bed', 21),
#  ('save', 21),
#  ('paid', 21),
#  ('character', 21),
#  ('formerl', 21),
#  ('alligator', 21),
#  ('q', 21),
#  ('indians', 20),
#  ('french', 20),
#  ('oil', 20),
#  ('ancient', 20),
#  ('safe', 20),
#  ('twentfive', 20),
#  ('spread', 20),
#  ('gulf', 20),
#  ('writing', 20),
#  ('condition', 20),
#  ('indeed', 20),
#  ('commerce', 20),
#  ('steamers', 20),
#  ('raft', 20),
#  ('possibl', 20),
#  ('clear', 20),
#  ('s', 20),
#  ('lie', 20),
#  ('horse', 20),
#  ('appeared', 20),
#  ('ling', 20),
#  ('allowed', 20),
#  ('threw', 20),
#  ('sat', 20),
#  ('follow', 20),
#  ('whereas', 20),
#  ('forth', 20),
#  ('building', 20),
#  ('cattle', 20),
#  ('approached', 19),
#  ('bound', 19),
#  ('live', 19),
#  ('gold', 19),
#  ('sea', 19),
#  ('fall', 19),
#  ('natche', 19),
#  ('hills', 19),
#  ('american', 19),
#  ('gentlemen', 19),
#  ('fight', 19),
#  ('written', 19),
#  ('blue', 19),
#  ('empt', 19),
#  ('news', 19),
#  ('future', 19),
#  ('natural', 19),
#  ('cold', 19),
#  ('minute', 19),
#  ('usual', 19),
#  ('shut', 19),
#  ('section', 19),
#  ('conversation', 19),
#  ('imagine', 19),
#  ('etc', 19),
#  ('grew', 19),
#  ('channel', 19),
#  ('spoke', 19),
#  ('stepped', 19),
#  ('strange', 19),
#  ('everwhere', 19),
#  ('remain', 19),
#  ('agreement', 19),
#  ('mabr', 19),
#  ('copright', 19),
#  ('anwhere', 18),
#  ('date', 18),
#  ('lightning', 18),
#  ('cotton', 18),
#  ('impossible', 18),
#  ('valle', 18),
#  ('drop', 18),
#  ('blow', 18),
#  ('important', 18),
#  ('islands', 18),
#  ('england', 18),
#  ('remark', 18),
#  ('buried', 18),
#  ('sense', 18),
#  ('consequentl', 18),
#  ('surface', 18),
#  ('arrived', 18),
#  ('dim', 18),
#  ('wood', 18),
#  ('dut', 18),
#  ('details', 18),
#  ('neck', 18),
#  ('reach', 18),
#  ('faces', 18),
#  ('hadnt', 18),
#  ('ourself', 18),
#  ('broad', 18),
#  ('supposed', 18),
#  ('reall', 18),
#  ('floor', 18),
#  ('isnt', 18),
#  ('required', 18),
#  ('simpl', 18),
#  ('orders', 18),
#  ('passenger', 18),
#  ('paper', 18),
#  ('tom', 18),
#  ('happ', 18),
#  ('leader', 18),
#  ('cop', 17),
#  ('laws', 17),
#  ('saved', 17),
#  ('dull', 17),
#  ('spirits', 17),
#  ('main', 17),
#  ('sixt', 17),
#  ('position', 17),
#  ('dr', 17),
#  ('although', 17),
#  ('closed', 17),
#  ('fashion', 17),
#  ('move', 17),
#  ('hunt', 17),
#  ('occasion', 17),
#  ('notice', 17),
#  ('return', 17),
#  ('meantime', 17),
#  ('green', 17),
#  ('following', 17),
#  ('grand', 17),
#  ('wall', 17),
#  ('suffering', 17),
#  ('walk', 17),
#  ('attempt', 17),
#  ('cincinnati', 17),
#  ('reckon', 17),
#  ('direction', 17),
#  ('lead', 17),
#  ('onder', 17),
#  ('stands', 17),
#  ('forecastle', 17),
#  ('ship', 17),
#  ('easil', 17),
#  ('danger', 17),
#  ('aside', 17),
#  ('shores', 17),
#  ('entirel', 17),
#  ('necessar', 17),
#  ('buo', 17),
#  ('cabin', 17),
#  ('tree', 17),
#  ('hill', 17),
#  ('nights', 17),
#  ('woods', 17),
#  ('considerable', 17),
#  ('beond', 17),
#  ('gentleman', 17),
#  ('stranger', 17),
#  ('railwa', 17),
#  ('race', 17),
#  ('food', 17),
#  ('certainl', 17),
#  ('backus', 17),
#  ('father', 16),
#  ('rising', 16),
#  ('cheap', 16),
#  ('makes', 16),
#  ('mumford', 16),
#  ('raised', 16),
#  ('care', 16),
#  ('flowers', 16),
#  ('shell', 16),
#  ('thrown', 16),
#  ('illinois', 16),
#  ('mere', 16),
#  ('stretch', 16),
#  ('forgotten', 16),
#  ('apparentl', 16),
#  ('value', 16),
#  ('spent', 16),
#  ('admiration', 16),
#  ('ahead', 16),
#  ('jumped', 16),
#  ('slow', 16),
#  ('crowd', 16),
#  ('storm', 16),
#  ('propert', 16),
#  ('heads', 16),
#  ('bright', 16),
#  ('judged', 16),
#  ('flat', 16),
#  ('pla', 16),
#  ('hair', 16),
#  ('points', 16),
#  ('instantl', 16),
#  ('scene', 16),
#  ('common', 16),
#  ('particularl', 16),
#  ('whenever', 16),
#  ('opportunit', 16),
#  ('bring', 16),
#  ('suppose', 16),
#  ('sstem', 16),
#  ('gra', 16),
#  ('shoal', 16),
#  ('reason', 16),
#  ('painted', 16),
#  ('ealer', 16),
#  ('mine', 16),
#  ('opposite', 16),
#  ('cause', 16),
#  ('cent', 16),
#  ('need', 16),
#  ('prison', 16),
#  ('brothers', 16),
#  ('curious', 15),
#  ('brick', 15),
#  ('surprise', 15),
#  ('national', 15),
#  ('spring', 15),
#  ('season', 15),
#  ('ohio', 15),
#  ('narrow', 15),
#  ('original', 15),
#  ('books', 15),
#  ('peculiar', 15),
#  ('henr', 15),
#  ('trifle', 15),
#  ('waiting', 15),
#  ('level', 15),
#  ('procession', 15),
#  ('cross', 15),
#  ('tremendous', 15),
#  ('throw', 15),
#  ('huge', 15),
#  ('break', 15),
#  ('lives', 15),
#  ('moon', 15),
#  ('destruction', 15),
#  ('round', 15),
#  ('laugh', 15),
#  ('sitting', 15),
#  ('pile', 15),
#  ('changes', 15),
#  ('power', 15),
#  ('officers', 15),
#  ('confidence', 15),
#  ('romantic', 15),
#  ('dalight', 15),
#  ('unless', 15),
#  ('answered', 15),
#  ('instant', 15),
#  ('mention', 15),
#  ('letters', 15),
#  ('broken', 15),
#  ('noticed', 15),
#  ('chute', 15),
#  ('mistake', 15),
#  ('stone', 15),
#  ('love', 15),
#  ('stle', 15),
#  ('horses', 15),
#  ('sick', 15),
#  ('flood', 15),
#  ('oconnor', 15),
#  ('donations', 15),
#  ('million', 14),
#  ('salle', 14),
#  ('shake', 14),
#  ('tourists', 14),
#  ('ding', 14),
#  ('signs', 14),
#  ('iron', 14),
#  ('stick', 14),
#  ('centur', 14),
#  ('needed', 14),
#  ('discovered', 14),
#  ('traveled', 14),
#  ('evening', 14),
#  ('print', 14),
#  ('pleasant', 14),
#  ('winter', 14),
#  ('connected', 14),
#  ('owners', 14),
#  ...]
